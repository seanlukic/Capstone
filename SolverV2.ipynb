# %%
import gurobipy as gp  # Import Gurobi optimization library
import pandas as pd  # Import pandas for data manipulation

# Comment out the code depending on the model 
import data_prep_Min  # Import data preparation module
import modeling_Min  # Import modeling module
from modeling_Min import T, R, W, Y, I, m  # Import tables, rounds, variables, people set, and model object


#import data_prep_Max
#from data_prep_Max import c, I, F, l, u
#import modeling_Max
#from modeling_Max import m, Y, W, Z
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2726179
# Academic license - for non-commercial use only - expires 2026-10-21

# %%
# Solve the model
m.optimize()  # Run Gurobi optimizer to find optimal solution

# EXTRACT SOLUTION
# ============================================================================
if m.status == gp.GRB.OPTIMAL:  # Check if optimal solution was found
    print(f"\nOptimal Solution Found - Total Penalty: {m.objVal:.1f}\n")  # Print objective value
    
    # Print table assignments for each round
    for r in R:  # Loop through all rounds
        print(f"\n=== ROUND {r} ===")  # Print round header
        for t in T:  # Loop through all tables
            if W[t, r].X > 0.5:  # If table t is used in round r
                people_in_t = [i for i in I if Y[i, t, r].X > 0.5]  # Get list of people assigned to table t in round r
                people_in_t.sort()  # Sort person IDs for cleaner output
                print(f"Table {t}: {len(people_in_t)} people (IDs: {', '.join(map(str, people_in_t))})")  # Print table assignment
else:  # If optimization did not find optimal solution
    print(f"\nOptimization failed with status {m.status}")  # Print failure status code
# Out:
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 25.2.0 25C56)
#
# CPU model: Apple M4
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 10234 rows, 2652 columns and 30127 nonzeros
# Model fingerprint: 0xd4dc4afe
# Variable types: 0 continuous, 2652 integer (2544 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [1e+01, 5e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+00]
# Found heuristic solution: objective 14400.000000
# Presolve removed 1877 rows and 1623 columns
# Presolve time: 0.02s
# Presolved: 8357 rows, 1029 columns, 26328 nonzeros
# Found heuristic solution: objective 13660.000000
# Variable types: 0 continuous, 1029 integer (1029 binary)
# Found heuristic solution: objective 13460.000000
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# ...
